# %%
from pennylane import numpy as np

symbols = ["H", "H", "H"]
x = np.array([0.028, 0.054, 0.0, 0.986, 1.610, 0.0, 1.855, 0.002, 0.0], requires_grad=True)

# %% [markdown]
# https://pennylane.ai/qml/demos/tutorial_mol_geo_opt/

# %% [markdown]
# import pennylane as qml
# def H(x):
#     return qml.qchem.molecular_hamiltonian(symbols, x, charge=1)[0] ## original

# %%
import pennylane as qml
import pickle
with open("C:/Users/lclai/Desktop/quantum/hamiltonian.pkl", "rb") as f:
    H = pickle.load(f)
def H(x):
    return H

# %%
hf = qml.qchem.hf_state(electrons=2, orbitals=6)
print(hf)
# Out:
# [1 1 0 0 0 0]

# %%
num_wires = 6
dev = qml.device("lightning.qubit", wires=num_wires)


@qml.qnode(dev, interface="autograd")
def circuit(params, obs, wires):
    qml.BasisState(hf, wires=wires)
    qml.DoubleExcitation(params[0], wires=[0, 1, 2, 3])
    qml.DoubleExcitation(params[1], wires=[0, 1, 4, 5])

    return qml.expval(obs)

# %%
def cost(params, x):
    hamiltonian = H(x)
    return circuit(params, obs=hamiltonian, wires=range(num_wires))

# %%
def finite_diff(f, x, delta=0.01):
    """Compute the central-difference finite difference of a function"""
    gradient = []

    for i in range(len(x)):
        shift = np.zeros_like(x)
        shift[i] += 0.5 * delta
        res = (f(x + shift) - f(x - shift)) * delta**-1
        gradient.append(res)

    return gradient


def grad_x(params, x):
    grad_h = finite_diff(H, x)
    grad = [circuit(params, obs=obs, wires=range(num_wires)) for obs in grad_h]
    return np.array(grad)

# %%
opt_theta = qml.GradientDescentOptimizer(stepsize=0.4)
opt_x = qml.GradientDescentOptimizer(stepsize=0.8)

# %%
from pennylane import numpy as np
theta = np.array([0.0, 0.0], requires_grad=True)

# %%
from functools import partial

# store the values of the cost function
energy = []

# store the values of the bond length
bond_length = []

# Factor to convert from Bohrs to Angstroms
bohr_angs = 0.529177210903

for n in range(100):

    # Optimize the circuit parameters
    theta.requires_grad = True
    x.requires_grad = False
    theta, _ = opt_theta.step(cost, theta, x)

    # Optimize the nuclear coordinates
    x.requires_grad = True
    theta.requires_grad = False
    _, x = opt_x.step(cost, theta, x, grad_fn=grad_x)

    energy.append(cost(theta, x))
    bond_length.append(np.linalg.norm(x[0:3] - x[3:6]) * bohr_angs)

    if n % 4 == 0:
        print(f"Step = {n},  E = {energy[-1]:.8f} Ha,  bond length = {bond_length[-1]:.5f} A")

    # Check maximum component of the nuclear gradient
    if np.max(grad_x(theta, x)) <= 1e-05:
        break

print("\n" f"Final value of the ground-state energy = {energy[-1]:.8f} Ha")
print("\n" "Ground-state equilibrium geometry")
print("%s %4s %8s %8s" % ("symbol", "x", "y", "z"))
for i, atom in enumerate(symbols):
    print(f"  {atom}    {x[3 * i]:.4f}   {x[3 * i + 1]:.4f}   {x[3 * i + 2]:.4f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 17
#      15 theta.requires_grad = True
#      16 x.requires_grad = False
# ---> 17 theta, _ = opt_theta.step(cost, theta, x)
#      19 # Optimize the nuclear coordinates
#      20 x.requires_grad = True
#
# File c:\Users\lclai\miniconda3\envs\envlaia\Lib\site-packages\pennylane\optimize\gradient_descent.py:93, in GradientDescentOptimizer.step(self, objective_fn, grad_fn, *args, **kwargs)
#      75 def step(self, objective_fn, *args, grad_fn=None, **kwargs):
#      76     """Update trainable arguments with one step of the optimizer.
#      77
#      78     Args:
#    (...)
#      90         If single arg is provided, list [array] is replaced by array.
#      91     """
# ---> 93     g, _ = self.compute_grad(objective_fn, args, kwargs, grad_fn=grad_fn)
#      94     new_args = self.apply_grad(g, args)
#      96     # unwrap from list if one argument, cleaner return
#
# File c:\Users\lclai\miniconda3\envs\envlaia\Lib\site-packages\pennylane\optimize\gradient_descent.py:122, in GradientDescentOptimizer.compute_grad(objective_fn, args, kwargs, grad_fn)
#     104 r"""Compute gradient of the objective function at the given point and return it along with
#     105 the objective function forward pass (if available).
#     106
#    (...)
#     119     will not be evaluted and instead ``None`` will be returned.
#     120 """
#     121 g = get_gradient(objective_fn) if grad_fn is None else grad_fn
# --> 122 grad = g(*args, **kwargs)
#     123 forward = getattr(g, "forward", None)
#     125 num_trainable_args = sum(getattr(arg, "requires_grad", False) for arg in args)
#
# File c:\Users\lclai\miniconda3\envs\envlaia\Lib\site-packages\pennylane\_grad.py:165, in grad.__call__(self, *args, **kwargs)
#     162     self._forward = self._fun(*args, **kwargs)
#     163     return ()
# --> 165 grad_value, ans = grad_fn(*args, **kwargs)  # pylint: disable=not-callable
#     166 self._forward = ans
#     168 return grad_value
#
# File c:\Users\lclai\miniconda3\envs\envlaia\Lib\site-packages\autograd\wrap_util.py:20, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f(*args, **kwargs)
#      18 else:
#      19     x = tuple(args[i] for i in argnum)
# ---> 20 return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#
# File c:\Users\lclai\miniconda3\envs\envlaia\Lib\site-packages\pennylane\_grad.py:183, in grad._grad_with_forward(fun, x)
#     177 @staticmethod
#     178 @unary_to_nary
#     179 def _grad_with_forward(fun, x):
#     180     """This function is a replica of ``autograd.grad``, with the only
#     181     difference being that it returns both the gradient *and* the forward pass
#     182     value."""
# --> 183     vjp, ans = _make_vjp(fun, x)  # pylint: disable=redefined-outer-name
#     185     if vspace(ans).size != 1:
#     186         raise TypeError(
#     187             "Grad only applies to real scalar-output functions. "
#     188             "Try jacobian, elementwise_grad or holomorphic_grad."
#     189         )
#
# File c:\Users\lclai\miniconda3\envs\envlaia\Lib\site-packages\autograd\core.py:10, in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# File c:\Users\lclai\miniconda3\envs\envlaia\Lib\site-packages\autograd\tracer.py:10, in trace(start_node, fun, x)
#       8 with trace_stack.new_trace() as t:
#       9     start_box = new_box(x, t, start_node)
# ---> 10     end_box = fun(start_box)
#      11     if isbox(end_box) and end_box._trace == start_box._trace:
#      12         return end_box._value, end_box._node
#
# File c:\Users\lclai\miniconda3\envs\envlaia\Lib\site-packages\autograd\wrap_util.py:15, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f.<locals>.unary_f(x)
#      13 else:
#      14     subargs = subvals(args, zip(argnum, x))
# ---> 15 return fun(*subargs, **kwargs)
#
# Cell In[15], line 3, in cost(params, x)
#       1 def cost(params, x):
#       2     hamiltonian = H(x)
# ----> 3     return circuit(params, obs=hamiltonian, wires=range(num_wires))
#
# File c:\Users\lclai\miniconda3\envs\envlaia\Lib\site-packages\pennylane\qnode.py:976, in QNode.__call__(self, *args, **kwargs)
#     973         kwargs["shots"] = _get_device_shots(self._original_device)
#     975 # construct the tape
# --> 976 self.construct(args, kwargs)
#     978 cache = self.execute_kwargs.get("cache", False)
#     979 using_custom_cache = (
#     980     hasattr(cache, "__getitem__")
#     981     and hasattr(cache, "__setitem__")
#     982     and hasattr(cache, "__delitem__")
#     983 )
#
# File c:\Users\lclai\miniconda3\envs\envlaia\Lib\site-packages\pennylane\qnode.py:862, in QNode.construct(self, args, kwargs)
#     859     self.interface = qml.math.get_interface(*args, *list(kwargs.values()))
#     861 with qml.queuing.AnnotatedQueue() as q:
# --> 862     self._qfunc_output = self.func(*args, **kwargs)
#     864 self._tape = QuantumScript.from_queue(q, shots)
#     866 params = self.tape.get_parameters(trainable_only=False)
#
# Cell In[14], line 11, in circuit(params, obs, wires)
#       8 qml.DoubleExcitation(params[0], wires=[0, 1, 2, 3])
#       9 qml.DoubleExcitation(params[1], wires=[0, 1, 4, 5])
# ---> 11 return qml.expval(obs)
#
# File c:\Users\lclai\miniconda3\envs\envlaia\Lib\site-packages\pennylane\measurements\expval.py:65, in expval(op)
#      60 if isinstance(op, Sequence):
#      61     raise ValueError(
#      62         "qml.expval does not support measuring sequences of measurements or observables"
#      63     )
# ---> 65 if not op.is_hermitian:
#      66     warnings.warn(f"{op.name} might not be hermitian.")
#      68 return ExpectationMP(obs=op)
#
# AttributeError: 'function' object has no attribute 'is_hermitian'

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
fig.set_figheight(5)
fig.set_figwidth(12)

# Add energy plot on column 1
E_fci = -1.27443765658
E_vqe = np.array(energy)
ax1 = fig.add_subplot(121)
ax1.plot(range(n + 1), E_vqe - E_fci, "go-", ls="dashed")
ax1.plot(range(n + 1), np.full(n + 1, 0.001), color="red")
ax1.set_xlabel("Optimization step", fontsize=13)
ax1.set_ylabel("$E_{VQE} - E_{FCI}$ (Hartree)", fontsize=13)
ax1.text(5, 0.0013, r"Chemical accuracy", fontsize=13)
plt.yscale("log")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add bond length plot on column 2
d_fci = 0.986
ax2 = fig.add_subplot(122)
ax2.plot(range(n + 1), bond_length, "go-", ls="dashed")
ax2.plot(range(n + 1), np.full(n + 1, d_fci), color="red")
ax2.set_ylim([0.965, 0.99])
ax2.set_xlabel("Optimization step", fontsize=13)
ax2.set_ylabel("bond length ($\AA$)", fontsize=13)
ax2.text(5, 0.9865, r"Equilibrium bond length", fontsize=13)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.subplots_adjust(wspace=0.3)
plt.show()
# Out:
# <>:27: SyntaxWarning: invalid escape sequence '\A'
# <>:27: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\lclai\AppData\Local\Temp\ipykernel_22788\1006237717.py:27: SyntaxWarning: invalid escape sequence '\A'
#   ax2.set_ylabel("bond length ($\AA$)", fontsize=13)
# C:\Users\lclai\AppData\Local\Temp\ipykernel_22788\1006237717.py:11: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "go-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(range(n + 1), E_vqe - E_fci, "go-", ls="dashed")
# C:\Users\lclai\AppData\Local\Temp\ipykernel_22788\1006237717.py:23: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "go-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(range(n + 1), bond_length, "go-", ls="dashed")
